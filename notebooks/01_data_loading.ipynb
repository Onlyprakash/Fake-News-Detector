# %%
import pandas as pd

# %%
df = pd.read_csv("../data/WELFake_Dataset.csv")

print("Original dataset shape:", df.shape)
print(df["label"].value_counts())
# Out:
# Original dataset shape: (72134, 4)
# label
# 1    37106
# 0    35028
# Name: count, dtype: int64

# %%
df["text"] = df["title"].fillna("") + " " + df["text"].fillna("")
df = df[["text", "label"]]

print("After selecting columns:", df.shape)
df.head()
# Out:
# After selecting columns: (72134, 2)
#                                                 text  label
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...      1
# 1     Did they post their votes for Hillary already?      1
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...      1
# 3  Bobby Jindal, raised Hindu, uses story of Chri...      0
# 4  SATAN 2: Russia unvelis an image of its terrif...      1

# %%
df.to_csv("../data/base_dataset.csv", index=False)
print("Base dataset saved successfully")
# Out:
# Base dataset saved successfully
